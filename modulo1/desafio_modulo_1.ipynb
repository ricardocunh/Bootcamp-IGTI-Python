# %% [markdown]
# **Código 1**

# %%
def funcao_1(num1, num2):
  resultado = num1 * num2



numero_1 = 20
numero_2 = 30

print(funcao_1(numero_1,numero_2))
# Out:
# None

# %% [markdown]
# **Código 2**

# %%
def funcao_2(num):
  numero_anterior = 0
  for i in list(range(num)):
    resultado = numero_anterior + i
    print("Numero A ", i, "Numero B ", numero_anterior, "Resultado: ", resultado)
    numero_anterior = i

funcao_2(10)
# Out:
# Numero A  0 Numero B  0 Resultado:  0
# Numero A  1 Numero B  0 Resultado:  1
# Numero A  2 Numero B  1 Resultado:  3
# Numero A  3 Numero B  2 Resultado:  5
# Numero A  4 Numero B  3 Resultado:  7
# Numero A  5 Numero B  4 Resultado:  9
# Numero A  6 Numero B  5 Resultado:  11
# Numero A  7 Numero B  6 Resultado:  13
# Numero A  8 Numero B  7 Resultado:  15
# Numero A  9 Numero B  8 Resultado:  17

# %% [markdown]
# **Código 3**

# %%
def funcao_4(lista_numerica):
  print("valor passado ", lista_numerica)
  a = lista_numerica[0]
  b = lista_numerica[-1]
  if (a == b):
    return True
  else:
    return False

numeros = [10, 20, 30, 40, 10]
print("result is", funcao_4(numeros))

# %% [markdown]
# **Código 4:**

# %%
def funcao_4(lista_numerica):
  print("valor passado ", lista_numerica)
  a = lista_numerica[0]
  b = lista_numerica[-1]
  if (a == b):
    return True
  else:
    return False

numeros = [12,3,23,11]

print(type(funcao_4(numeros)))
# Out:
# valor passado  [12, 3, 23, 11]
# <class 'bool'>

# %% [markdown]
# **Código 5**

# %%
class Classe_1:
  def funcao_da_classe_1(self, string):
    dicionario = {'I' : 1, 'V': 5, 'X': 10, 'L': 50, 'C' : 100, 'D': 500, 'M': 1000}
    valor = 0
    for i in range(len(string)):
      if i > 0 and dicionario[string[i]] > dicionario[string[i - 1]]:
        valor += dicionario[string[i]] - 2 * dicionario[string[i - 1]]
      else:
        valor += dicionario[string[i]]
      return valor

mod = Classe_1()
mod.funcao_da_classe_1('III')
# Out:
# 1

# %% [markdown]
# **Código 6**

# %%
class A:
  def __init__(self):
    self.calcI(30)
    print("i da Classe A", self.i)

  def calcI(self, i):
    self.i = 2 * i;

class B(A):
  def __init__(self):
    #super() acessando a classe do metodo PAI
    super().__init__()

  def calcI(self, i):
    self.i = 3 * i;

b = B()
# Out:
# i da Classe A 90

# %% [markdown]
# **Código 7**

# %%
class Classe_2():
  def __init__(self, l, w):
    self.a = l
    self.b = w

  def metodo_1(self):
    return self.a*self.b

objeto_1 = Classe_2(12, 10)

print(objeto_1)
# Out:
# <__main__.Classe_2 object at 0x7ffbc8396898>
