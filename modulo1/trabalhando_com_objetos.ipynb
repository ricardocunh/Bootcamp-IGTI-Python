# %% [markdown]
# **import < nome_do_modulo >**

# %%
# acessando o local onde os módulos estão armazenados

import sys
print(sys.path)
# Out:
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython']

# %%
#utilizando módulos em python
import math #módulo que contém as funções matemáticas

print("O valor de pi é: ",math.pi)  # valor de pi
print("O valor de 45º é: ",math.sin(math.pi/4)) # seno de pi/4
print("O valor de 180º é: ",math.cos(math.pi))  #cosseno de pi
# Out:
# O valor de pi é:  3.141592653589793
# O valor de 45º é:  0.7071067811865475
# O valor de 180º é:  -1.0

# %% [markdown]
# **Import < modulo_1 >[ < modulo_2 > ...]**

# %%
import math, datetime

print(datetime.datetime.now())
# Out:
# 2020-08-13 10:40:01.963677

# %%
# utilizando módulos "build-in" em python

print("Módulo string: ", str(124))
print("Módulo float: ",float(123/12))
# Out:
# Módulo string:  124
# Módulo float:  10.25

# %%
import platform # módulo utilizado para monitorar a plataforma (S.O) que estamos utilizando

x = platform
plataforma=x.system()
print(plataforma)
print(x.python_version())
print(x.processor)
# Out:
# Linux
# 3.6.9
# <function processor at 0x7f4fc5e888c8>

# %%
# utilizando a minha própria função
import meu_modulo

meu_modulo.print_boas_vindas("Ricardo")
# Out:
# Olá, Ricardo. Tudo bem com você?

# %% [markdown]
# **O módulo só é carregado uma vez**

# %%
# mostrando que o carregamento só ocorre uma vez
import modulo_teste
# Out:
# [100, 200, 300]

# %%
import modulo_teste

# %% [markdown]
# **O from módulo import atributo**

# %% [markdown]
# 1. Importamos apenas o que interessa;
# 2. Não importa todo mundo;

# %%
# realizando um import da maneira "mais certa"
from math import factorial
numero=5
print("O fatorial de {} é {}".format(numero,factorial(numero)))
# Out:
# O fatorial de 5 é 120

# %% [markdown]
# # from < nome_do_modulo > import*

# %%
# utilizando o * para importar tudo
from math import *
numero=6
print("O fatorial de {} é {}".format(numero,factorial(numero)))
# Out:
# O fatorial de 6 é 720

# %% [markdown]
# **from < nome_do_modulo > import < nome > as < nome_alternativo >**

# %%
import meu_modulo as modulo_1
modulo_1.print_boas_vindas("Ricardo")
# Out:
# Olá, Ricardo. Tudo bem com você?

# %% [markdown]
# **A tabela de lista de nomes em Python**

# %%
# monstrando a tabela de nomes existentes
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  '_sh',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'datetime',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exit',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'get_ipython',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'math',
#  'meu_modulo',
#  'modf',
#  'modulo_1',
#  'modulo_teste',
#  'nan',
#  'numero',
# ...

# %%
# verificando os nomes definidos pelo módulo
import math

conteudo = dir(math)
print(conteudo)
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'pi', 'pow', 'radians', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %% [markdown]
# **Instalando novos módulos no Google Colab**

# %%
# !pip install ColabTurtle
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.0.0-cp36-none-any.whl size=4033 sha256=edbc42eb9b7ed6dbf0a55b1f87cdaaafd315577b2cecd587c61846402087385d
#   Stored in directory: /root/.cache/pip/wheels/a8/29/ec/ad346f0042ae467cc74f4378916348faf975b07890651dcae7
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle import Turtle #importando o módulo

# %%
t=Turtle
t.initializeTurtle()
t.forward(25)
t.left(72.5)
t.forward(25)
t.left(72.5)
t.forward(25)
t.left(72.5)
t.forward(25)
t.left(72.5)
t.forward(25)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="225.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="225.0" x2="376.15707623129435" y2="217.48235501239319" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="376.15707623129435" y1="217.48235501239319" x2="361.8176653225182" y2="237.96115611961798" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="361.8176653225182" y1="237.96115611961798" x2="377.03670104773624" y2="257.7949896268989" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="377.03670104773624" y1="257.7949896268989" x2="400.52901656738396" y2="249.24448604375718" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(250.0,400.52901656738396,249.24448604375718) translate(400.52901656738396, 249.24448604375718)">
# ...

# %% [markdown]
# # **Pacotes (packages) em Python**

# %%
import pacotes.modulo_1, pacotes.modulo_2

pacotes.modulo_1.facao_isso()
pacotes.modulo_2.faca_isso_tambem()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-e771e07e2f1e> in <module>()
#       1 import pacotes.modulo_1, pacotes.modulo_2
#       2
# ----> 3 pacotes.modulo_1.facao_isso()
#       4 pacotes.modulo_2.faca_isso_tambem()
#
# AttributeError: module 'pacotes.modulo_1' has no attribute 'facao_isso'

# %% [markdown]
# # **Construtores**

# %% [markdown]
# < nome_do_objeto > = < Classe > ( < argumento > )

# %%
# Criando uma classe carro
class Carro:
  def __init__(self,numero_portas,preco):
    self.numero_portas=numero_portas
    self.preco=preco 
    print("Objeto carro instanciado com sucesso.")
  def get_numero_portas(self):
    return self.numero_portas

carro_1=Carro(4,50000)
# Out:
# Objeto carro instanciado com sucesso.

# %%
portas_carro_1=carro_1.get_numero_portas()
print("Meu carro possui %d portas." %portas_carro_1)
# Out:
# Meu carro possui 4 portas.

# %%
carro_2=Carro(2,80000)
portas_carro_2=carro_2.get_numero_portas()
print("Meu carro possui %d portas." %portas_carro_2)
# Out:
# Objeto carro instanciado com sucesso.
# Meu carro possui 2 portas.

# %% [markdown]
# **Métodos acessores e modificadores**
#
# * GETTERS (Métodos Acessores)
# * SETTERS (Métodos Modificadores)

# %%
# importando o módulo array
import array as ar

# %%
# inicializando o array
meu_array = ar.array('i', [5, 1, 3, 4, 2, 2, 7])

# %%
# print do array
print(meu_array)

#acessando o indice do valor igual a 2
print(meu_array.index(2))

# acessando a quantia de valores 2 existentes
print(meu_array.count(2))
# Out:
# array('i', [5, 1, 3, 4, 2, 2, 7])
# 4
# 2

# %% [markdown]
# # **Herança**

# %% [markdown]
# Exemplo:  CARRO É UMA SUPERCLASSE, CLASSE PAI, CLASSE BASE DE TAXI!

# %% [markdown]
# TAXI É UM CARRO!

# %% [markdown]
# TAXI É UMA SUBCLASSE, CLASSE FILHA, CLASSE DERIVADA DE CARRO!

# %% [markdown]
# * Permite reutilizar o código;
# * A subclasse ou classe filha, obtém todos os atributos da classe pai;
# * A classe filha pode adicionar novos atributos ou funções
# * Para a classe filha não é necessário escrever todo o código da classe pai

# %%
# sintaxe da herança em python
class ClassPai:
  '''Corpo da classe pai.'''
class ClassFilha(ClassPai):
  '''Corpo da classe filha.'''

# %%
# definindo a classe formas
class Formas:
  def __init__(self,x,y):
    self.x = x
    self.y = y
  descricao = "A forma ainda não foi denida"
  autor  = "Ainda não foi definido um autor para ela."
  def area(self):
    return self.x * self.y
  def get_perimetro(self):
    return 2 * self.x + 2 * self.y
  def set_descricao(self,texto):
    self.descricao = texto
  def set_nome_do_autor(self,texto):
    self.autor = texto
  def set_escala(self,escala):
    self.x = self.x * escala
    self.y = self.y * escala

# %%
# instanciando um retângulo
retangulo=Formas(5,8)

# %%
retangulo.area()
# Out:
# 40

# %%
# definindo um quadrado
quadrado=Formas(3,3)

# %%
# poderia definir uma classe do tipo quadrado, pois ela é um quadrado
class Quadrado(Formas):
  def __init__(self,x):
    self.x = x
    self.y = x

# %%
# definindo um quadrado a partir da classe filha
quadrado=Quadrado(3)

# %%
# acessando os demais métodos
quadrado.area()
# Out:
# 9

# %%
# acessando os atributos
quadrado.descricao
# Out:
# 'A forma ainda não foi denida'

# %%
# adicionando novos métodos para a classe quadrado
class Quadrado(Formas):
  def __init__(self,x):
    self.x = x
    self.y = x
  def perimetro_do_quadrado(self):
    return (self.x)*4

# %%
# definindo um quadrado a partir da classe filha
quadrado=Quadrado(10)

# %%
# utilizando um método da classe pai
quadrado.set_nome_do_autor('Ricardo Cunha')

# %%
# utilizando um método "exclusivo" da classe filha
quadrado.perimetro_do_quadrado()
# Out:
# 40
