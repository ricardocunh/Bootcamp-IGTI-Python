# %% [markdown]
# **Faça isso de novo... Faça isso até... Repita mais x vezes...**

# %% [markdown]
# **O que são objetos?**

# %%
s = "Como vai você?"

# %%
type(s) #todo tipo correspondente
# Out:
# str

# %% [markdown]
# **Tudo em Python são objetos**
#
# referencia_ao_objeto.metodo(argumentos)

# %%
# Definimos o objeto string
s = "COMO VAI VOCÊ?"
nova_string=s.lower()
print(nova_string)
# Out:
# como vai você?
