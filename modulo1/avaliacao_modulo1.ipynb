# %% [markdown]
# **Codigo 1**

# %%
idade = int(input("Entre com sua idade:"))
nova_idade = idade + 1
print("No próximo ano você terá: {} anos.".format(nova_idade))
# Out:
# Entre com sua idade:33.3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4a7f9a730b99> in <module>()
# ----> 1 idade = int(input("Entre com sua idade:"))
#       2 nova_idade = idade + 1
#       3 print("No próximo ano você terá: {} anos.".format(nova_idade))
#
# ValueError: invalid literal for int() with base 10: '33.3'

# %% [markdown]
# **Codigo 2**

# %%
lado_a=35
lado_b=14.33333
area_do_retangulo= (lado_a)*(lado_b)
print("O retângulo de lado A = %d e lado B = %.2f é %.3f " %(lado_a,lado_b,area_do_retangulo))
# Out:
# O retângulo de lado A = 35 e lado B = 14.33 é 501.667

# %% [markdown]
# **Codigo 3**

# %%
lista_1 = [1,2,'IGTI']
lista_2 = [2,3,"Bootcamp"]
lista_3=lista_1+lista_2
print(lista_3)
# Out:
# [1, 2, 'IGTI', 2, 3, 'Bootcamp']

# %% [markdown]
# **Codigo 4**

# %%
chute=int(input("Entre com um valor inteiro de 0 a 30: "))
adivinhacao=[5, 6, 10, 14, 16, 20, 30]
if chute in adivinhacao:
  print("Você acertou um dos números que eu estava pensando.")

  if chute > 15:
    print("Esse número é maior do que 20.")
  if chute < 20:
    print("Esse número é menos que 20.")

  print("Você é fera.")
else:
    print("Que penam você errou. Pode tentar outra vez.")
print('Obrigado por participar')
# Out:
# Entre com um valor inteiro de 0 a 30: 4
# Que penam você errou. Pode tentar outra vez.
# Obrigado por participar

# %% [markdown]
# **Codigo 5**

# %%
frutas = ["maça", "banana", "uva", "goiaba"]
for x in frutas:
  if x == "uva":
    
    print(x)
# Out:
# uva

# %% [markdown]
# **Codigo 6**

# %%
n = 5
while n >= 0:
  n -= 1
  print(n)
# Out:
# 4
# 3
# 2
# 1
# 0
# -1
