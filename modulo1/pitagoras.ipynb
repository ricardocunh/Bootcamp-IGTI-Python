# %%
#aplicando o teorema de pitágoras
b = 3
c = 4
# B elevado a dois + C elevado a dois
a2=(b**2)+(c**2)
print(a2)
# Out:
# 25

# %%
#Calculando a raiz da hipotenusa (a)
a=a2**0.5
print('O valor da hipotenusa (a) é : ',a)
# Out:
# O valor da hipotenusa (a) é :  5.0
